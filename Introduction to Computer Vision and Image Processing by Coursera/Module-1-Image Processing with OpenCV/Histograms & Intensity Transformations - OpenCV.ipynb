# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %% [markdown]
# # An Helper function to plot the two image side by side

# %%
def plot_image(First_image, Second_image, title_1 = "Original", title_2 = "New Image"):
    plt.Figure(figsize=(10,10))
    plt.Subplot(1,2,1)
    plt.imshow(First_image, cmap="gray")
    plt.title(title_1)
    
    plt.Subplot(1,2,2)
    plt.imshow(Second_image, cmap="gray")
    plt.title(title_2)
    plt.show()

# %% [markdown]
# *** Lets define another helper function. The following one will plot two histograms side-by-side. Again, you do not need to understand the body of this function at this moment ***

# %%
def plot_hist(old_image, new_image,title_old="Orignal", title_new="New Image"):
    intensity_values=np.array([x for x in range(256)])
    plt.subplot(1, 2, 1)
    plt.bar(intensity_values, cv2.calcHist([old_image],[0],None,[256],[0,256])[:,0],width = 5)
    plt.title(title_old)
    plt.xlabel('intensity')
    plt.subplot(1, 2, 2)
    plt.bar(intensity_values, cv2.calcHist([new_image],[0],None,[256],[0,256])[:,0],width = 5)
    plt.title(title_new)
    plt.xlabel('intensity')
    plt.show()

# %% [markdown]
# # Histograms

# %%
toy_image = np.array([[0,2,2],[1,1,1],[1,1,2]],dtype=np.uint8)
plt.imshow(toy_image, cmap="gray")
plt.show()
print("toy_image:",toy_image)
# Out:
# toy_image: [[0 2 2]
#  [1 1 1]
#  [1 1 2]]

# %%
plt.bar([x for x in range(7)],[1,5,3,4,2,0,9])
plt.show()

# %%
plt.hist(toy_image.flatten(),bins=3)
plt.show()

# %%
plt.bar([x for x in range(6)],[0,1,0,5,0,2])
plt.show()

# %% [markdown]
# # Gray Scale Histograms¶

# %%
img = cv2.imread(r'D:\B - Computer Vision Library Tutorials and Projects Collection\Computer-Vision\Introduction to Computer Vision and Image Processing by Coursera\Images\lenna.png', cv2.IMREAD_GRAYSCALE)
# Display the image using Matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(img, cmap="gray")
plt.title("Grayscale Image of Lenna")
plt.axis('off')  # Hide the axes for a cleaner look
plt.show()

# %%
hist = cv2.calcHist([img],[0],None, [256],[0,256])

# %%
hist.argmax()
# Out:
# np.int64(59)

# %%
intensity_values = np.array([x for x in range(hist.shape[0])])
plt.bar(intensity_values, hist[:,0], width = 5)
plt.title("Bar histogram")
# plt.axhline(hist[116])
plt.show()

# %%
img = cv2.imread(r'D:\B - Computer Vision Library Tutorials and Projects Collection\Computer-Vision\Introduction to Computer Vision and Image Processing by Coursera\Images\baboon.png')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
color = ('blue','green','red')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(intensity_values,histr,color = col,label=col+" channel")
    
    plt.xlim([0,256])
plt.legend()
plt.title("Histogram Channels")
plt.show()
